# %% [markdown]
# ## OVERVIEW OF OSEMiN

# %% [markdown]
# <img src='https://raw.githubusercontent.com/jirvingphd/fsds_100719_cohort_notes/master/images/OSEMN.png' width=800>
#
# <center><a href="https://www.kdnuggets.com/2018/02/data-science-command-line-book-exploring-data.html">
#     </a></center>
#
#
# > <font size=2em>The Data Science Process we'll be using during this section--OSEMiN (pronounced "OH-sum", rhymes with "possum").  This is the most straightforward of the Data Science Processes discussed so far.  **Note that during this process, just like the others, the stages often blur together.***  It is completely acceptable (and ***often a best practice!) to float back and forth** between stages as you learn new things about your problem, dataset, requirements, etc.
# It's quite common to get to the modeling step and realize that you need to scrub your data a bit more or engineer a different feature and jump back to the "Scrub" stage, or go all the way back to the "Obtain" stage when you realize your current data isn't sufficient to solve this problem.
# As with any of these frameworks, *OSEMiN is meant to be treated as guidelines, not law.
# </font>
#
#
# ### OSEMN DETAILS
#
# **OBTAIN**
#
# - This step involves understanding stakeholder requirements, gathering information on the problem, and finally sourcing data that we think will be necessary for solving this problem.
#
# **SCRUB**
#
# - During this stage, we'll focus on preprocessing our data.  Important steps such as identifying and removing null values, dealing with outliers, normalizing data, and feature engineering/feature selection are handled around this stage.  The line with this stage really blurs with the _Explore_ stage, as it is common to only realize that certain columns require cleaning or preprocessing as a result of the visualzations and explorations done during Step 3.
#
# - Note that although technically, categorical data should be one-hot encoded during this step, in practice, it's usually done after data exploration.  This is because it is much less time-consuming to visualize and explore a few columns containing categorical data than it is to explore many different dummy columns that have been one-hot encoded.
#
# **EXPLORE**
#
# - This step focuses on getting to know the dataset you're working with. As mentioned above, this step tends to blend with the _Scrub_ step mentioned above.  During this step, you'll create visualizations to really get a feel for your dataset.  You'll focus on things such as understanding the distribution of different columns, checking for multicollinearity, and other tasks liek that.  If your project is a classification task, you may check the balance of the different classes in your dataset.  If your problem is a regression task, you may check that the dataset meets the assumptions necessary for a regression task.
#
# - At the end of this step, you should have a dataset ready for modeling that you've thoroughly explored and are extremely familiar with.
#
# **MODEL**
#
# - This step, as with the last two frameworks, is also pretty self-explanatory. It consists of building and tuning models using all the tools you have in your data science toolbox.  In practice, this often means defining a threshold for success, selecting machine learning algorithms to test on the project, and tuning the ones that show promise to try and increase your results.  As with the other stages, it is both common and accepted to realize something, jump back to a previous stage like _Scrub_ or _Explore_, and make some changes to see how it affects the model.
#
# **iNTERPRET**
#
# - During this step, you'll interpret the results of your model(s), and communicate results to stakeholders.  As with the other frameworks, communication is incredibily important! During this stage, you may come to realize that further investigation is needed, or more data.  That's totally fine--figure out what's needed, go get it, and start the process over! If your results are satisfactory to all stakeholders involved, you may also go from this stage right into productionizing your model and automating processes necessary to support it.

# %% [markdown]
# ## PROCESS CHECKLIST

# %% [markdown]
# > Keep in mind that it is normal to jump between the OSEMN phases and some of them will blend together, like SCRUB and EXPLORE.

# %% [markdown]
# 1. **[OBTAIN](#OBTAIN)**
#     - Import data, inspect, check for datatypes to convert and null values
#     - Display header and info.
#     - Drop any unneeded columns, if known (`df.drop(['col1','col2'],axis=1,inplace=True`)
#     <br><br>
#
#
# 2. **[SCRUB](#SCRUB)**
#     - Recast data types, identify outliers, check for multicollinearity, normalize data**
#     - Check and cast data types
#         - [ ] Check for #'s that are store as objects (`df.info()`,`df.describe()`)
#             - when converting to #'s, look for odd values (like many 0's), or strings that can't be converted.
#             - Decide how to deal weird/null values (`df.unique()`, `df.isna().sum()`)
#             - `df.fillna(subset=['col_with_nulls'],'fill_value')`, `df.replace()`
#         - [ ] Check for categorical variables stored as integers.
#             - May be easier to tell when you make a scatter plotm or `pd.plotting.scatter_matrix()`
#
#     - [ ] Check for missing values  (df.isna().sum())
#         - Can drop rows or colums
#         - For missing numeric data with median or bin/convert to categorical
#         - For missing categorical data: make NaN own category OR replace with most common category
#     - [ ] Check for multicollinearity
#         - Use seaborn to make correlation matrix plot
#         - Good rule of thumb is anything over 0.75 corr is high, remove the variable that has the most correl with the largest # of variables
#     - [ ] Normalize data (may want to do after some exploring)
#         - Most popular is Z-scoring (but won't fix skew)
#         - Can log-transform to fix skewed data
#
#
# 3. **[EXPLORE](#EXPLORE)**
#     - [ ] Check distributions, outliers, etc**
#     - [ ] Check scales, ranges (df.describe())
#     - [ ] Check histograms to get an idea of distributions (df.hist()) and data transformations to perform.
#         - Can also do kernel density estimates
#     - [ ] Use scatter plots to check for linearity and possible categorical variables (`df.plot("x","y")`)
#         - categoricals will look like vertical lines
#     - [ ] Use `pd.plotting.scatter_matrix(df)` to visualize possible relationships
#     - [ ] Check for linearity.
#
#
# 4. **[MODEL](#MODEL)**
#
#     - **Fit an initial model:**
#         - Run an initial model and get results
#
#     - **Holdout validation / Train/test split**
#         - use sklearn `train_test_split`
#
#
# 5. **[iNTERPRET](#iNTERPRET)**
#     - **Assessing the model:**
#         - Assess parameters (slope,intercept)
#         - Check if the model explains the variation in the data (RMSE, F, R_square)
#         - *Are the coeffs, slopes, intercepts in appropriate units?*
#         - *Whats the impact of collinearity? Can we ignore?*
#         <br><br>
#     - **Revise the fitted model**
#         - Multicollinearity is big issue for lin regression and cannot fully remove it
#         - Use the predictive ability of model to test it (like R2 and RMSE)
#         - Check for missed non-linearity
#
#
# 6. **Interpret final model and draw >=3 conclusions and recommendations from dataset**

# %% [markdown]
# <div style="display:block;border-bottom:solid red 3px;padding:1.4em;color:red;font-size:30pt;display:inline-block;line-height:1.5em;">
# DELETE THIS CELL AND EVERYTHING ABOVE FROM YOUR FINAL NOTEBOOK
# </div>

# %% [markdown]
# # Final Project Submission

# %% [markdown]
# Please fill out:
# * Student name: Jessica Miles
# * Student pace: Full Time
# * Scheduled project review date/time:
# * Instructor name: James Irving

# %% [markdown]
# ## TABLE OF CONTENTS

# %% [markdown]
# *Click to jump to matching Markdown Header.*<br><br>
#
# - **[Introduction](#INTRODUCTION)<br>**
# - **[OBTAIN](#OBTAIN)**<br>
# - **[SCRUB](#SCRUB)**<br>
# - **[EXPLORE](#EXPLORE)**<br>
# - **[MODEL](#MODEL)**<br>
# - **[iNTERPRET](#iNTERPRET)**<br>
# - **[Conclusions/Recommendations](#CONCLUSIONS-&-RECOMMENDATIONS)<br>**
# ___

# %% [markdown]
# # INTRODUCTION

# %% [markdown]
# ## Business Problem
#
# Acme Real Estate Association would like to use data to understand how they can serve their customers better and increase their business. They would like to create marketing and educational material to enable their team of agents to make informed recommendations to customers about how to increase home sale prices. Although they already have plenty of experience and domain expertise, they want to confirm their intuitions and back it up with real data.
#
# The two main questions they have are:
# 1. Which home features contribute most to higher sale price? Acme wants information about all factors which contribute significantly to sale price, so they can confirm their team's intuitions and educate their customers.
# 2. What are the most effective strategies homeowners can employ to increase the eventual sale price of their home? This should focus on features homeowners can control.

# %% [markdown]
# # OBTAIN

# %% [markdown]
# ## Data Understanding
#
# For this project, we will use data from home sales where Acme is based, in King County, WA.
#
# Our data spans about a year between May 2, 2014 and May 27, 2015. It includes homes sold in most zip codes in King County, with the exception of zip codes in the heart of downtown Seattle.
# ***
# Questions to consider:
# * Where did the data come from, and how do they relate to the data analysis questions?
# * What do the data represent? Who is in the sample and what variables are included?
# * What is the target variable?
# * What are the properties of the variables you intend to use?
# ***

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import missingno as msno
from scipy import stats
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm
from statsmodels.formula.api import ols

# %% [markdown]
# ## Initial Import

# %%
# import raw data
df_raw = pd.read_csv('data/kc_house_data.csv')
df_raw.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0         NaN   0.0  ...      7        1180            0.0
# 1      7242     2.0         0.0   0.0  ...      7        2170          400.0
# 2     10000     1.0         0.0   0.0  ...      6         770            0.0
# 3      5000     1.0         0.0   0.0  ...      7        1050          910.0
# 4      8080     1.0         0.0   0.0  ...      8        1680            0.0
#
#   yr_built  yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15
# ...

# %%
df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21597 non-null  int64
#  1   date           21597 non-null  object
#  2   price          21597 non-null  float64
#  3   bedrooms       21597 non-null  int64
#  4   bathrooms      21597 non-null  float64
#  5   sqft_living    21597 non-null  int64
#  6   sqft_lot       21597 non-null  int64
#  7   floors         21597 non-null  float64
#  8   waterfront     19221 non-null  float64
#  9   view           21534 non-null  float64
#  10  condition      21597 non-null  int64
#  11  grade          21597 non-null  int64
#  12  sqft_above     21597 non-null  int64
#  13  sqft_basement  21597 non-null  object
#  14  yr_built       21597 non-null  int64
#  15  yr_renovated   17755 non-null  float64
#  16  zipcode        21597 non-null  int64
# ...

# %% [markdown]
# ## Explore Dates

# %%
# Explore the date range of sales that we have

#Convert to datetime type
df_raw['date'] = pd.to_datetime(df_raw['date'])

# Explore date range that we have
df_raw['date'].describe(datetime_is_numeric=True)
# Out:
# count                            21597
# mean     2014-10-29 04:20:38.171968512
# min                2014-05-02 00:00:00
# 25%                2014-07-22 00:00:00
# 50%                2014-10-16 00:00:00
# 75%                2015-02-17 00:00:00
# max                2015-05-27 00:00:00
# Name: date, dtype: object

# %% [markdown]
# Dates range from May 2, 2014 to May 27, 2015.

# %% [markdown]
# ## Explore Zip Codes

# %%
# Explore the zip codes included. Does it include all the zip codes in King County?
df_zips = df_raw['zipcode'].value_counts()
df_zips
# Out:
# 98103    602
# 98038    589
# 98115    583
# 98052    574
# 98117    553
#         ...
# 98102    104
# 98010    100
# 98024     80
# 98148     57
# 98039     50
# Name: zipcode, Length: 70, dtype: int64

# %% [markdown]
# We have 70 zip codes in our data set. Data points per zip code range from 50 over the year to 602 over the year, which sounds reasonable.

# %%
# Import zip code information for all zip codes in King County, 
# scraped from https://www.unitedstateszipcodes.org on 4-9-2021.
zips = pd.read_csv('data/king_county_zips.tsv', delimiter='\t', index_col=0)
zips
# Out:
#       % of County Population      Type     Primary City  \
# ZIP
# 98001                     2%  Standard           Auburn
# 98002                     2%  Standard           Auburn
# 98092                     2%  Standard           Auburn
# 98224                   0.0%    PO Box           Baring
# 98004                     1%  Standard         Bellevue
# ...                      ...       ...              ...
# 98065                   0.7%  Standard       Snoqualmie
# 98068                   0.0%    PO Box  Snoqualmie Pass
# 98070                   0.6%  Standard           Vashon
# 98072                   1.0%  Standard      Woodinville
# 98077                   0.7%  Standard      Woodinville
#
#                                        Acceptable Cities  \
# ZIP
# 98001                                Algona, Federal Way
# 98002                                                NaN
# 98092                                                NaN
# ...

# %% [markdown]
# We have 87 zip codes in this list, so there should be 17 that are in this list but not in our main data. Which are they?
#
# Acceptable Cities appear to be alternative city names that the US Post Office will accept, whereas Unacceptable Cities are the cities the Post Office does not officially recognize.

# %%
# Match up raw data with current King County zip code data and check out any
# discrepancies. Primary goal is to make sure we have all the zip codes, or
# at least enough to not need to worry about having an actually random sample.

joined_df = zips.join(df_zips, how='left')
joined_df[joined_df['zipcode'].isna()].sort_values('% of County Population')
# Out:
#       % of County Population      Type     Primary City Acceptable Cities  \
# ZIP
# 98224                   0.0%    PO Box           Baring               NaN
# 98195                   0.0%    Unique          Seattle               NaN
# 98174                   0.0%  Standard          Seattle               NaN
# 98164                   0.0%  Standard          Seattle               NaN
# 98158                   0.0%  Standard          Seattle            Seatac
# 98154                   0.0%  Standard          Seattle               NaN
# 98134                   0.0%  Standard          Seattle               NaN
# 98288                   0.0%    PO Box        Skykomish               NaN
# 98068                   0.0%    PO Box  Snoqualmie Pass     Snoqualmie Ps
# 98050                   0.0%    PO Box          Preston               NaN
# 98354                   0.0%  Standard           Milton               NaN
# 98051                   0.2%  Standard       Ravensdale               NaN
# ...

# %% [markdown]
# So we do have 17 zip codes in King County as of 2021 which aren't represented in our main dataset of houses sold back in 2014-2015.
#
# Many of them represent 0.0% of the county's population, so maybe there simply weren't any houses sold in those zip codes during the year time period we're looking at.
#
# On the other hand, 98104, 98101, 98121, 98174, 98154, 98164 are all in downtown Seattle. So it appears that the housing price data set we have excludes these. Since the factors that contribute to increased prices for downtown apartments may be different from the factors that contribute to increased prices of houses in the suburbs, it's acceptable to exclude the main downtown zips. However, this is an important caveat.

# %%
# Understand the View column better
df_raw[df_raw['view'] > 0]
# Out:
#                id       date      price  bedrooms  bathrooms  sqft_living  \
# 15     9297300055 2015-01-24   650000.0         4       3.00         2950
# 21     2524049179 2014-08-26  2000000.0         3       2.75         3050
# 49      822039084 2015-03-11  1350000.0         3       2.50         2753
# 58     7922800400 2014-08-27   951000.0         5       3.25         3250
# 60     1516000055 2014-12-10   650000.0         3       2.25         2150
# ...           ...        ...        ...       ...        ...          ...
# 21538  2855000110 2014-08-08   388000.0         3       2.50         2198
# 21560  9253900271 2015-01-07  3570000.0         5       4.50         4850
# 21563  7011201004 2014-05-29   645000.0         3       3.25         1730
# 21577  8672200110 2015-03-17  1090000.0         5       3.75         4170
# 21582  8956200760 2014-10-13   541800.0         4       2.50         3118
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# ...

# %% [markdown]
# ## Extended understanding of columns

# %% [markdown]
# King County's data portal allow searching and running area reports. The glossary of one area report I ran contained the following definitions for grade and condition, which I will assume are the same definitions used in 2014 and 2015 when these houses were sold.
#
# **Condition: Relative to Age and Grade**
# - 1= Poor Many repairs needed. Showing serious deterioration.
# - 2= Fair Some repairs needed immediately. Much deferred maintenance.
# - 3= Average Depending upon age of improvement; normal amount of upkeep for the age
# of the home.
# - 4= Good Condition above the norm for the age of the home. Indicates extra attention
# and care has been taken to maintain.
# - 5= Very Good Excellent maintenance and updating on home. Not a total renovation.
#
# **Residential Building Grades**
# - Grades 1 - 3 Falls short of minimum building standards. Normally cabin or inferior structure.
# - Grade 4 Generally older low quality construction. Does not meet code.
# - Grade 5 Lower construction costs and workmanship. Small, simple design.
# - Grade 6 Lowest grade currently meeting building codes. Low quality materials, simple designs.
# - Grade 7 Average grade of construction and design. Commonly seen in plats and older subdivisions.
# - Grade 8 Just above average in construction and design. Usually better materials in both the exterior and interior finishes.
# - Grade 9 Better architectural design, with extra exterior and interior design and quality.
# - Grade 10 Homes of this quality generally have high quality features. Finish work is better, and more design quality is seen in the floor plans and larger square footage.
# - Grade 11 Custom design and higher quality finish work, with added amenities of solid woods, bathroom fixtures and more luxurious options.
# - Grade 12 Custom design and excellent builders. All materials are of the highest quality and all conveniences are present.
# - Grade 13 Generally custom designed and built. Approaching the Mansion level. Large amount of highest quality cabinet work, wood trim and marble; large entries
#
# https://www.kingcounty.gov/depts/assessor/Reports/area-reports/2020/residential-westcentral/~/media/depts/assessor/documents/AreaReports/2020/Residential/013.ashx

# %% [markdown]
# In addition, reviewing the report from the King County database itself led me to question the definition of the "View" column as provided. The column definitions provided describe this column as "Has been viewed", which sounds as if it has been viewed by prospective buyers, or perhaps by an assessor. However, only 2,110 rows out of the 21k total rows, or about 10% have a value in this column greater than 0.
#
# Reviewing a single property with a "View" value of 4 on the King County Parcel Viewer reveals that the property detail report includes a section for whether a property has views, and that the property with a value of 4 is said to have views in two categories. I conclude that the View column represents whether a property has views of natural features. Since it will not be feasible to determine what the numbers mean, I will likely turn this column into a category of has view, versus does not have view.
#
# https://blue.kingcounty.com/Assessor/eRealProperty/Detail.aspx?ParcelNbr=2524049166

# %% [markdown]
# # SCRUB

# %% [markdown]
# ## Data Preparation
#
# Describe and justify the process for preparing the data for analysis.
#
# ***
# Questions to consider:
# * Were there variables you dropped or created?
# * How did you address missing values or outliers?
# * Why are these choices appropriate given the data and the business problem?
# ***

# %%
df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21597 non-null  int64
#  1   date           21597 non-null  datetime64[ns]
#  2   price          21597 non-null  float64
#  3   bedrooms       21597 non-null  int64
#  4   bathrooms      21597 non-null  float64
#  5   sqft_living    21597 non-null  int64
#  6   sqft_lot       21597 non-null  int64
#  7   floors         21597 non-null  float64
#  8   waterfront     19221 non-null  float64
#  9   view           21534 non-null  float64
#  10  condition      21597 non-null  int64
#  11  grade          21597 non-null  int64
#  12  sqft_above     21597 non-null  int64
#  13  sqft_basement  21597 non-null  object
#  14  yr_built       21597 non-null  int64
#  15  yr_renovated   17755 non-null  float64
#  16  zipcode        21597 non-null  int64
# ...

# %% [markdown]
# ## Check for Duplicates

# %%
# check for duplicates
df_raw[df_raw.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [id, date, price, bedrooms, bathrooms, sqft_living, sqft_lot, floors, waterfront, view, condition, grade, sqft_above, sqft_basement, yr_built, yr_renovated, zipcode, lat, long, sqft_living15, sqft_lot15]
# Index: []
#
# [0 rows x 21 columns]

# %%
# check for duplicate based on date, lat and long, just to be extra sure
dupe_cols = ['date', 'lat', 'long']

df_raw[df_raw.duplicated(subset=dupe_cols, 
                         keep=False)][dupe_cols + ['id', 'price']].sort_values(dupe_cols)
# Out:
#             date      lat     long          id     price
# 19730 2014-07-23  47.6948 -122.178  9492500160  889950.0
# 20341 2014-07-23  47.6948 -122.178  9492500170  879950.0
# 19930 2014-08-04  47.6070 -122.053  1042700300  829995.0
# 21128 2014-08-04  47.6070 -122.053  1042700290  864327.0
# 19616 2014-08-04  47.6536 -122.354  1972200554  580000.0
# 19976 2014-08-04  47.6536 -122.354  1972200553  619000.0
# 11614 2014-08-21  47.6340 -122.033  6817801040  440000.0
# 18197 2014-08-21  47.6340 -122.033  6817801020  475000.0
# 8000  2014-09-09  47.4349 -122.328  9325200110  569950.0
# 19137 2014-09-09  47.4349 -122.328  9325200120  600600.0
# 961   2014-09-16  47.6233 -122.319  6852700478  425000.0
# 14398 2014-09-16  47.6233 -122.319  6852700477  550000.0
# 20338 2014-09-18  47.3710 -122.018   255450020  367899.0
# 20809 2014-09-18  47.3710 -122.018   255450030  369946.0
# 6996  2014-10-27  47.6751 -122.379  2767601100  513000.0
# ...

# %% [markdown]
# I used Google Maps to look up the address of a few of these properties using their lat/long coordinates, and then plugged the addresses into the King County Parcel Viewer (https://www.kingcounty.gov/services/gis/Maps/parcel-viewer.aspx) to view the property history.
#
# - ID 9492500160 / ID 9492500170: this is a single property, that was BUILT in 2014. The price listed is \$879,950.00, which is the smaller of the two values we have.
# - ID 6852700478 / 6852700477: Also looks like a single property, sale date in December 2014 (doesn't match our data) and price listed is $752,000, which also doesn't match our data. This is much higher than our data.
#
# Without going through all of them, I'm going to have a difficult time figuring out which are accurate. Since there aren't many, I'm going to drop these rows.

# %%
# drop duplicates based on long, lat, and date
df_raw.drop_duplicates(keep=False, subset=dupe_cols, inplace=True)

# check to make sure we don't have the duplicates now
df_raw[df_raw.duplicated(subset=dupe_cols, 
                         keep=False)][dupe_cols + ['id', 'price']].sort_values(dupe_cols)
# Out:
# Empty DataFrame
# Columns: [date, lat, long, id, price]
# Index: []

# %%
# Check for houses that were sold twice within the year time period
df_raw[df_raw.duplicated(subset=['id'], 
                         keep=False)].sort_values(['id','date'])
# Out:
#                id       date     price  bedrooms  bathrooms  sqft_living  \
# 2494      1000102 2014-09-16  280000.0         6       3.00         2400
# 2495      1000102 2015-04-22  300000.0         6       3.00         2400
# 16800     7200179 2014-10-16  150000.0         2       1.00          840
# 16801     7200179 2015-04-24  175000.0         2       1.00          840
# 11421   109200390 2014-08-20  245000.0         3       1.75         1480
# ...           ...        ...       ...       ...        ...          ...
# 6340   9828200460 2015-01-06  430000.0         2       1.00          700
# 15185  9834200305 2014-07-16  350000.0         3       1.00         1790
# 15186  9834200305 2015-02-10  615000.0         3       1.00         1790
# 1084   9834200885 2014-07-17  360000.0         4       2.50         2080
# 1085   9834200885 2015-04-20  550000.0         4       2.50         2080
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# ...

# %% [markdown]
# Going to keep the last sale and get rid of prior ones.

# %%
# Drop houses sold multiple times, keep latest one
df_raw.drop_duplicates(subset=['id'], keep='last', inplace=True)

# %% [markdown]
# ## Check for null values

# %%
# We have null values in the following columns
cols_w_nulls = ['yr_renovated', 'waterfront', 'view']

def print_uniques(df_raw, col_list):
    for col in col_list:
        print(col)
        print(np.sort(df_raw[col].unique()))
        print()
    return None

print_uniques(df_raw, cols_w_nulls)
# Out:
# yr_renovated
# [   0. 1934. 1940. 1944. 1945. 1946. 1948. 1950. 1951. 1953. 1954. 1955.
#  1956. 1957. 1958. 1959. 1960. 1962. 1963. 1964. 1965. 1967. 1968. 1969.
#  1970. 1971. 1972. 1973. 1974. 1975. 1976. 1977. 1978. 1979. 1980. 1981.
#  1982. 1983. 1984. 1985. 1986. 1987. 1988. 1989. 1990. 1991. 1992. 1993.
#  1994. 1995. 1996. 1997. 1998. 1999. 2000. 2001. 2002. 2003. 2004. 2005.
#  2006. 2007. 2008. 2009. 2010. 2011. 2012. 2013. 2014. 2015.   nan]
#
# waterfront
# [ 0.  1. nan]
#
# view
# [ 0.  1.  2.  3.  4. nan]

# %%
# Visualize where the nulls fall
msno.matrix(df_raw)
# Out:
# <AxesSubplot:>

# %% [markdown]
# There doesn't appear to be any regular pattern with respect to nulls across the few columns where I have them.
#
# For all 3 columns, will replace nulls with 0s, assuming these properties don't have a record of renovation, don't have waterfront access, or don't have a view.

# %%
# replace nans with 0s for cols with nulls

for col in cols_w_nulls:
    df_raw.loc[df_raw[col].isna(), col] = 0

# %%
# check that it worked
print_uniques(df_raw, cols_w_nulls)
# Out:
# yr_renovated
# [   0. 1934. 1940. 1944. 1945. 1946. 1948. 1950. 1951. 1953. 1954. 1955.
#  1956. 1957. 1958. 1959. 1960. 1962. 1963. 1964. 1965. 1967. 1968. 1969.
#  1970. 1971. 1972. 1973. 1974. 1975. 1976. 1977. 1978. 1979. 1980. 1981.
#  1982. 1983. 1984. 1985. 1986. 1987. 1988. 1989. 1990. 1991. 1992. 1993.
#  1994. 1995. 1996. 1997. 1998. 1999. 2000. 2001. 2002. 2003. 2004. 2005.
#  2006. 2007. 2008. 2009. 2010. 2011. 2012. 2013. 2014. 2015.]
#
# waterfront
# [0. 1.]
#
# view
# [0. 1. 2. 3. 4.]

# %% [markdown]
# ## Correct Column DTypes

# %%
# sqft basement appears to be the wrong type
df_raw['sqft_basement'].value_counts()
# Out:
# 0.0       12699
# ?           452
# 600.0       215
# 500.0       206
# 700.0       206
#           ...
# 2720.0        1
# 946.0         1
# 276.0         1
# 1798.0        1
# 1281.0        1
# Name: sqft_basement, Length: 304, dtype: int64

# %% [markdown]
# OK so we have some values with question marks, which caused these to be classified as strings instead of floats.
#
# Slightly more than half have a value of 0, so no basement. Going to convert the question marks to 0s.

# %%
# Convert question marks to 0s
df_raw.loc[df_raw['sqft_basement'] == '?', 'sqft_basement'] = 0.0

# Convert column to float
df_raw['sqft_basement'] = df_raw['sqft_basement'].astype('float64')

# confirm changes were made
print(df_raw['sqft_basement'].dtype)
df_raw['sqft_basement'].value_counts()
# Out:
# float64
# 0.0       13151
# 600.0       215
# 500.0       206
# 700.0       206
# 800.0       201
#           ...
# 915.0         1
# 295.0         1
# 1281.0        1
# 2130.0        1
# 906.0         1
# Name: sqft_basement, Length: 303, dtype: int64

# %%
df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21398 entries, 0 to 21596
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21398 non-null  int64
#  1   date           21398 non-null  datetime64[ns]
#  2   price          21398 non-null  float64
#  3   bedrooms       21398 non-null  int64
#  4   bathrooms      21398 non-null  float64
#  5   sqft_living    21398 non-null  int64
#  6   sqft_lot       21398 non-null  int64
#  7   floors         21398 non-null  float64
#  8   waterfront     21398 non-null  float64
#  9   view           21398 non-null  float64
#  10  condition      21398 non-null  int64
#  11  grade          21398 non-null  int64
#  12  sqft_above     21398 non-null  int64
#  13  sqft_basement  21398 non-null  float64
#  14  yr_built       21398 non-null  int64
#  15  yr_renovated   21398 non-null  float64
#  16  zipcode        21398 non-null  int64
# ...

# %% [markdown]
# Now all of my columns are fully populated, with no duplicates or nulls, and are the data type I want.
#
# Let's loop through each column and get a little summary to understand which we might want to turn into categories.

# %% [markdown]
# I want to create the following features:
# - Years since last renovation (sale year minus renovated date, or yr_built if renovated year is 0)
# - bedrooms per sqft_living
# - bathrooms per sqft_living
# - Percent of living space above ground (divided by total above ground and basement)
# - Has view versus not has a view

# %% [markdown]
# # EXPLORE

# %%
def explore_data(to_explore, df, target, hist=True, box=True, plot_v_target=True,
                 summarize=True, norm_check=True):

    # want to take each column, do a histogram, a box plot, plot it versus the target
    # then do an analysis of column type and number of unique values to determine 
    # whether it might be a categorical variable continuous. If categorical,
    # get the unique values and counts. If continuous, do a describe.
    # also check for normality
    
    # Create some variables to dynamically handle including/excluding certain charts
    num_charts = 0
    if hist:
        num_charts += 1
    if box:
        num_charts += 1 
    if plot_v_target:
        num_charts += 1
    
    # column headers for metadata output df
    meta_list = [['col_name', 'corr_target', 'assumed_var_type', 'omnibus_k2',
                 'omnibus_pstat', 'is_normal', 'uniques', 'mean', 'median']]
    
    # loop through each column in the list to analyze
    for col in to_explore:
        
        header_line = '-'*75
        header_text = f'\nSummary of Data for column: {col}\n'
        print(header_line + header_text + header_line)
        
        # Determine if categorical or continuous
        # assume continuous to begin with
        var_type = 'continuous'
        uniques = np.nan
        mean = np.nan
        median = np.nan
        
        if df[col].dtype in ['int64', 'float64']:
            # number types need the most analysis because they could be
            # categorical even if they're numeric
            num_uniques = len(df[col].unique())
            # using 100 as an arbitrary cutoff here, may need adjustment
            if num_uniques < 20:
                var_type = 'categorical'
                uniques = num_uniques
            else:
                mean = np.mean(df[col])
                median = np.median(df[col])
        elif df[col].dtype in ['object']:
            # Assuming column types have been fixed at this point,
            # so if a column is not numerical it must be categorical
            var_type = 'categorical'
            uniques = num_uniques
        elif df[col].dtype in ['datetime64']:
            var_type = 'date'
            
        # print summary based on data type
        if summarize:
            if var_type in ['continuous', 'date']:
                print(df[col].describe())
            else:
                with pd.option_context('display.max_rows', 20):
                    print(df[col].value_counts())
        
        if num_charts > 0:
            
            fig, axes = plt.subplots(nrows=num_charts, ncols=1, 
                                     figsize=(8, num_charts * 5))
            if hist:
                if num_charts > 1:
                    ax1 = axes[0]
                else:
                    ax1 = axes
                    
                if box:
                    ax2 = axes[1]
                    if plot_v_target:
                        ax3 = axes[2]
                elif plot_v_target:
                    ax3 = axes[1]
            elif box:
                if num_charts > 1:
                    ax2 = axes[0]
                else:
                    ax2 = axes
            
                if plot_v_target:
                    ax3 = axes[1]
                    
            elif plot_v_target:
                ax3 = axes

            
            # add a little extra space for headers
            plt.subplots_adjust(hspace=0.3)

            # Histogram
            if hist:
                sns.histplot(df[col], kde=True, ax=ax1)
                ax1.set_title(f"Hist {col}")

            # Box plot
            if box:
                sns.boxplot(x=df[col], ax=ax2)
                ax2.set_title(f"Boxplot {col}")

            # Plot against target
            # create a series representing quartiles, to use as hue
            if plot_v_target:                
                if var_type == 'continuous':
                    try:
                        quartile_labels=['q1', 'q2', 'q3', 'q4']
                        quartiles = pd.qcut(df[col], 4, labels=quartile_labels, duplicates='drop')
                        sns.scatterplot(x=df[col], y=df[target], ax=ax3, hue=quartiles)
                        ax3.legend(title=f'{col} quartiles')
                    except:
                        sns.scatterplot(x=df[col], y=df[target], ax=ax3)
                else:
                    sns.scatterplot(x=df[col], y=df[target], ax=ax3)
                ax3.set_title(f"{col} versus {target}")
                
            plt.show();

        # get pearson correlation coefficient between col and target
        corr = df[[col, target]].corr()
        
        # Test for normality using scipy omnibus normality test
        # null hypothesis is that the data comes from a normal distribution
        if norm_check:
            k2, p = stats.normaltest(df[col])
            if p < 0.05:
                normal = False
                print(f'\nData is NOT normal with p-statistic = {p}\n')
            else:
                normal = True
                print(f'\nData IS normal with p-statistic = {p}\n')
            
        # append metadata to list of lists
        meta_list.append([col, corr.iloc[0][1], var_type, k2, p, normal, 
            uniques, mean, median])
        
    df_meta = pd.DataFrame(data=meta_list[1:], columns=meta_list[0])
    return df_meta

# %% [markdown]
# ## Run initial column summary reports and graphs

# %%
explore_cols = df_raw.drop(labels=['price', 'lat', 'long', 'id', 'date', 
                                   'sqft_living15', 'sqft_lot15'], axis=1
                          ).columns
explore_cols
# Out:
# Index(['bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
#        'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'condition_new',
#        'has_basement', 'year_sold', 'years_since_reno'],
#       dtype='object')

# %%
df_meta = explore_data(explore_cols, df_raw, 'price')
# Out:
# ---------------------------------------------------------------------------
# Summary of Data for column: bedrooms
# ---------------------------------------------------------------------------
# 3     9724
# 4     6844
# 2     2729
# 5     1583
# 6      265
# 1      191
# 7       38
# 8       13
# 9        6
# 10       3
# 11       1
# Name: bedrooms, dtype: int64
# Data is NOT normal with p-statistic = 0.0
#
# I got here!
# ---------------------------------------------------------------------------
# Summary of Data for column: bathrooms
# ---------------------------------------------------------------------------
# count    21397.000000
# mean         2.118416
# std          0.768598
# min          0.500000
# 25%          1.750000
# 50%          2.250000
# 75%          2.500000
# max          8.000000
# Name: bathrooms, dtype: float64
# Data is NOT normal with p-statistic = 0.0
#
# I got here!
# ---------------------------------------------------------------------------
# ...

# %%
df_meta.sort_values('corr_target', ascending=False)
# Out:
#          col_name  corr_target assumed_var_type    omnibus_k2  omnibus_pstat  \
# 2     sqft_living     0.701447       continuous   6798.561480            0.0
# 8           grade     0.666942      categorical   2239.807458            0.0
# 9      sqft_above     0.604557       continuous   5952.212235            0.0
# 1       bathrooms     0.525399       continuous   1439.840714            0.0
# 6            view     0.392932      categorical  14728.882977            0.0
# 10  sqft_basement     0.321462       continuous   6263.218160            0.0
# 0        bedrooms     0.309591      categorical  13574.044301            0.0
# 5      waterfront     0.264953      categorical  36132.089117            0.0
# 4          floors     0.254958      categorical   1536.123350            0.0
# 12   yr_renovated     0.118379       continuous  20849.859790            0.0
# 3        sqft_lot     0.088827       continuous  38527.666417            0.0
# ...

# %% [markdown]
# ## Make adjustments based on reviewing summary

# %% [markdown]
# ### Bedroom

# %%
# Bedrooms looks to have an extreme outlier
df_raw[df_raw['bedrooms'] == 33]
# Out:
#                id       date     price  bedrooms  bathrooms  sqft_living  \
# 15856  2402100895 2014-06-25  640000.0        33       1.75         1620
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 15856      6000     1.0         0.0   0.0  ...      7        1040
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 15856          580.0      1947           0.0    98103  47.6878 -122.331
#
#        sqft_living15  sqft_lot15
# 15856           1330        4700
#
# [1 rows x 21 columns]

# %%
# Dropping this outlier because it looks like the info was recorded incorrectly
df_raw.drop(labels=df_raw[df_raw['bedrooms'] == 33].index, axis=0, inplace=True)

df_raw[df_raw['bedrooms'] == 33]
# Out:
# Empty DataFrame
# Columns: [id, date, price, bedrooms, bathrooms, sqft_living, sqft_lot, floors, waterfront, view, condition, grade, sqft_above, sqft_basement, yr_built, yr_renovated, zipcode, lat, long, sqft_living15, sqft_lot15]
# Index: []
#
# [0 rows x 21 columns]

# %%
explore_data(['bedrooms'], df_raw, 'price')
# Out:
# ---------------------------------------------------------------------------
# Summary of Data for column: bedrooms
# ---------------------------------------------------------------------------
# 3     9724
# 4     6844
# 2     2729
# 5     1583
# 6      265
# 1      191
# 7       38
# 8       13
# 9        6
# 10       3
# 11       1
# Name: bedrooms, dtype: int64
# Data is NOT normal with p-statistic = 0.0
#    col_name  corr_target assumed_var_type   omnibus_k2  omnibus_pstat  \
# 0  bedrooms     0.316877      categorical  1840.008483            0.0
#
#    is_normal  uniques  mean  median
# 0      False       11   NaN     NaN

# %%
df_raw[(df_raw['bedrooms'] == 4) & (df_raw['price'] <= 200000)]
# Out:
#                id       date     price  bedrooms  bathrooms  sqft_living  \
# 97     1099611230 2014-09-12  199000.0         4       1.50         1160
# 118    3454800060 2015-01-08  171800.0         4       2.00         1570
# 827    1610000016 2014-09-11  175000.0         4       1.00         1300
# 880    2349300060 2015-02-12  200000.0         4       2.00         1920
# 1735   5402100045 2015-03-11  189950.0         4       2.00         1910
# ...           ...        ...       ...       ...        ...          ...
# 19355  3353401340 2015-02-16  199900.0         4       1.75         1790
# 19442  1545807180 2015-05-06  190000.0         4       1.75         1900
# 19547    42000245 2014-06-13  171000.0         4       2.00         1520
# 19600  1446400564 2014-05-07  185000.0         4       1.00         1490
# 20791  6056100160 2014-07-28  182568.0         4       1.50         1500
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# ...

# %%
# Visualize how sq_ft living compares to number of bedrooms
quartile_labels=['q1', 'q2', 'q3', 'q4']
quartiles = pd.qcut(df_raw['sqft_living'], 4, labels=quartile_labels)

fig, ax = plt.subplots()
sns.scatterplot(x=df_raw['bedrooms'], y=df_raw['sqft_living'], hue=quartiles)
ax.legend(title='Sq Fit Living')
plt.show();

# %% [markdown]
# I looked up two properties that appeared to have more bedrooms than would be reasonable for the sqft_living area and the data in this set did not match King County's current records. Need to come back to this as unsure how to fix it.

# %% [markdown]
# ### Bathroom

# %%
## Plot bathrooms versus bedrooms to try to identify outliers or bad data
# I believe they should more or less correlate

fig, ax = plt.subplots()
sns.scatterplot(x=df_raw['bedrooms'], y=df_raw['bathrooms'])
plt.show();

# %% [markdown]
# Some of these certainly sound weird to me (a 6-bedroom house with 8 bathrooms?) but not totally outside the realm of possibility.

# %% [markdown]
# ### Sq Ft Living

# %%
df_raw[df_raw['sqft_living'] < 500]
# Out:
#                id       date     price  bedrooms  bathrooms  sqft_living  \
# 465    8658300340 2014-05-23   80000.0         1       0.75          430
# 860    1723049033 2014-06-20  245000.0         1       0.75          380
# 1166   3523029041 2014-10-09  290000.0         2       0.75          440
# 4199   1437500015 2014-07-09  150000.0         3       0.75          490
# 8126   7849202585 2014-09-04  170000.0         1       1.00          480
# 8614   6303400395 2015-01-30  325000.0         1       0.75          410
# 11488  4322200105 2015-03-31  229050.0         1       1.00          420
# 12063  8655900162 2015-02-19  156000.0         1       0.75          470
# 14452  7549801385 2014-06-12  280000.0         1       0.75          420
# 15234  1320069249 2014-10-20  192500.0         1       1.00          470
# 15367  2856101479 2014-07-01  276000.0         1       0.75          370
# 17380   745000005 2014-08-25  145000.0         1       0.75          480
# ...

# %% [markdown]
# Houses under 500 sq ft. These could be tiny houses or mobile homes.

# %% [markdown]
# ### Sq Ft Lot

# %%
# Review quartiles for sq ft lot
df_raw['sqft_lot'].quantile(q=[0, .25, .5, .75, 1])
# Out:
# 0.00        520.0
# 0.25       5040.0
# 0.50       7617.0
# 0.75      10698.0
# 1.00    1651359.0
# Name: sqft_lot, dtype: float64

# %%
df_raw[df_raw['sqft_lot'] > 500000]
# Out:
#                id       date      price  bedrooms  bathrooms  sqft_living  \
# 1717   1020069017 2015-03-27   700000.0         4       1.00         1300
# 2962   2322029048 2014-11-19   999000.0         3       2.75         2830
# 3945    722069232 2014-09-05   998000.0         4       3.25         3770
# 4437   3626079040 2014-07-30   790000.0         2       3.00         2560
# 4536   2522029039 2014-09-29   550000.0         3       2.00         3650
# 6685   2624089007 2015-03-20  2000000.0         2       2.50         3900
# 7070   2724079090 2015-01-05  1650000.0         4       3.25         3920
# 7287   1923039022 2014-11-20   700000.0         2       1.75         1679
# 7640   2623069031 2014-05-21   542500.0         5       3.25         3010
# 7762   2323089009 2015-01-19   855000.0         4       3.50         4030
# 9705    225079036 2015-01-07   937500.0         4       4.00         5545
# 12906   820079043 2014-08-19   428000.0         3       1.75         1580
# ...

# %% [markdown]
# ### Floors

# %%
# Check out houses with half floors, do they have basements?
df_floors = df_raw.loc[df_raw['floors'].isin([1.5, 2.5, 3.5]) == True, 
                       ['floors','sqft_basement']].copy()

temp = df_floors['sqft_basement'] > 0
temp.value_counts()
# Out:
# False    1263
# True      792
# Name: sqft_basement, dtype: int64

# %% [markdown]
# Some of the houses that have half floors also have basement sq footage, but most do not. Going to adjust the floors to round down to nearest whole number.

# %%
# round floor down to nearest whole number
df_raw['floors'] = df_raw['floors'].map(lambda x: int(x))

# %%
# check values
df_raw['floors'].value_counts()
# Out:
# 1    12430
# 2     8353
# 3      614
# Name: floors, dtype: int64

# %% [markdown]
# ### View

# %%
# convert to binary yes/no
df_raw['view'] = df_raw['view'].map(lambda x: 1 if x > 0 else 0)
df_raw['view'].value_counts()
# Out:
# 0    19294
# 1     2103
# Name: view, dtype: int64

# %% [markdown]
# ### Condition

# %%
# Create a new column indicating over or under average condition
df_raw['condition_new'] = df_raw['condition'].map(lambda x : 1 if x > 3 
                                          else (-1 if x < 3 else 0))

print(df_raw['condition_new'].value_counts())
print(f"Null count (average) = {df_raw['condition_new'].isna().sum()}")
# Out:
#  0    13882
#  1     7326
# -1      189
# Name: condition_new, dtype: int64
# Null count (average) = 0

# %%
# plot new condition against price
explore_data(['condition_new'], df_raw, 'price', hist=False, box=False)
# Out:
# ---------------------------------------------------------------------------
# Summary of Data for column: condition_new
# ---------------------------------------------------------------------------
#  0    13882
#  1     7326
# -1      189
# Name: condition_new, dtype: int64
# Data is NOT normal with p-statistic = 0.0
#         col_name  corr_target assumed_var_type    omnibus_k2  omnibus_pstat  \
# 0  condition_new     0.012863      categorical  19983.508608            0.0
#
#    is_normal  uniques  mean  median
# 0      False        3   NaN     NaN

# %% [markdown]
# This really didn't do much. I'm not going to use Condition in my model because it doesn't look like it's correlated with price at all.

# %% [markdown]
# ### Sq Ft Basement

# %%
## Convert to has basement yes/no
df_raw['has_basement'] = df_raw['sqft_basement'].map(lambda x : 1 if x > 0 else 0)
df_raw['has_basement'].value_counts()
# Out:
# 0    13151
# 1     8246
# Name: has_basement, dtype: int64

# %%
explore_data(['has_basement'], df_raw, 'price', hist=False, box=False)
# Out:
# ---------------------------------------------------------------------------
# Summary of Data for column: has_basement
# ---------------------------------------------------------------------------
# 0    13151
# 1     8246
# Name: has_basement, dtype: int64
# Data is NOT normal with p-statistic = 0.0
#        col_name  corr_target assumed_var_type    omnibus_k2  omnibus_pstat  \
# 0  has_basement     0.178531      categorical  86226.287945            0.0
#
#    is_normal  uniques  mean  median
# 0      False        2   NaN     NaN

# %% [markdown]
# ### Yr Renovated

# %%
# Create feature for years since renovation, or since built if never renovated
df_raw['year_sold'] = df_raw['date'].dt.year

def years_since_reno(row):
    #print(row)
    if row['yr_renovated'] > 0:
        years = row['year_sold'] - row['yr_renovated']
    else:
        years = row['year_sold'] - row['yr_built']
    return years

df_raw['years_since_reno'] = df_raw.apply(lambda x: years_since_reno(x), axis=1)

df_raw['years_since_reno'].value_counts()
# Out:
#  9.0      491
#  0.0      488
#  8.0      477
#  11.0     457
#  10.0     453
#          ...
#  113.0     27
#  115.0     23
# -1.0       18
#  81.0      16
#  80.0      15
# Name: years_since_reno, Length: 117, dtype: int64

# %%
# check out these negative values, figuring these are within same year
df_raw[df_raw['years_since_reno'] < 0]
# Out:
#                id       date     price  bedrooms  bathrooms  sqft_living  \
# 1761   1832100030 2014-06-25  597326.0         4       4.00         3570
# 2293   8712100320 2014-07-28  585000.0         5       2.75         2350
# 2685   3076500830 2014-10-29  385195.0         1       1.00          710
# 7090   9141100005 2014-10-28  285000.0         4       3.50         2770
# 7519   9520900210 2014-12-31  614285.0         5       2.75         2730
# 8032   1250200495 2014-06-24  455000.0         2       1.50         1200
# 11587  7284900030 2014-05-22  850000.0         4       3.25         3090
# 14475  2770601530 2014-08-26  500000.0         2       2.25         1570
# 14845  3585900665 2014-06-06  805000.0         5       2.50         4600
# 15673  3585900190 2014-10-06  825000.0         3       2.50         3400
# 17084  9126100346 2014-06-17  350000.0         3       2.00         1380
# 18560  8935100100 2014-07-01  476000.0         4       3.00         2890
# ...

# %%
# update years_since_reno to be 0 when negative
df_raw.loc[df_raw['years_since_reno'] < 0, ['years_since_reno']] = 0
df_raw['years_since_reno'].value_counts()
# Out:
# 0.0      506
# 9.0      491
# 8.0      477
# 11.0     457
# 10.0     453
#         ...
# 79.0      32
# 113.0     27
# 115.0     23
# 81.0      16
# 80.0      15
# Name: years_since_reno, Length: 116, dtype: int64

# %%
# Plot years_since_reno against price
explore_data(['years_since_reno'], df_raw, 'price')
# Out:
# ---------------------------------------------------------------------------
# Summary of Data for column: years_since_reno
# ---------------------------------------------------------------------------
# count    21397.000000
# mean        41.289760
# std         28.946773
# min          0.000000
# 25%         16.000000
# 50%         37.000000
# 75%         61.000000
# max        115.000000
# Name: years_since_reno, dtype: float64
# Data is NOT normal with p-statistic = 0.0
#            col_name  corr_target assumed_var_type   omnibus_k2  omnibus_pstat  \
# 0  years_since_reno    -0.094534       continuous  1466.289511            0.0
#
#    is_normal  uniques      mean  median
# 0      False      NaN  41.28976    37.0

# %% [markdown]
# ## Learnings from initial exploration
#
# ### Bedroom
# - Had an extreme outlier with 33 rooms, which was dropped since it seems implausible.
# - Isn't truly continuous since you can't have 2.74 bedrooms, but going to leave as continuous for now. Should consider breaking into categories using quartiles.
# - Interestingly, not a very strong correlation between bedrooms and price. Is it really possible that there are 4+ bedroom houses for sale under \$200k? **Need to return to this and figure out whether I can drop some of these**
#
# ### Bathroom
# - Need to treat as continuous, since can have bathrooms in full steps, half-steps, and 3/4 steps.
# - Generally correlated to price.
# - Shape is roughly normal but not actually.
# - Interesting that bathroom counts of 2.5 and 1 are by far the most common, followed by 1.75. Perhaps I can use something here to help answer my question about how much value adding another half bath adds.
#
# ### Sqft Living
# - Min is 370 sq ft, which seems very low. Took a look though and will leave those in.
# - There are probably some outliers on the high end that I may want to consider removing.
# - Sq ft living does generally correlate with price
#
# ### Sqft Lot
# - There are some very large lots listed here with over 1 MM square ft. Checked out one that had only a 1 bd house and it looked correct.
# - While there are some very large lots, 75% are about 10k and under.
#
# ### Floors
# - Some houses have half floors, which are probably basements or attics.
# - The majority of houses have 1 floor, next most common is 2 floors, with only very few having half floors or 2.
# - Some houses listed as having half floors also have basements, so the half floor could be the basement, but it could also indicate a split level house or the extra floor could be an attic room. Going to round down to nearest whole floor.
#
# ### Waterfront
# - Very few properties are on the waterfront; only 146 out of all 21.5k. It's already in a binary / dummy column so will leave as is.
# - Looking at Waterfront plotted against price, waterfront properties seem to start at a slightly higher price than non-waterfront, but they each seem to have a pretty good spread.
#
# ### View
# - Very few properties have a view. Going to standardize into Yes/No binary column
#
# ### Condition
# - The majority of houses are condition 3, which is described as 'average' so that makes sense.
# - Attempted to categorize condition further. Tried only looking at below and above average homes, where <3 = -1, >3 = 1 and average = 0. The correlation with price actually went down.
# _ Concluding that Condition ranking does not have much affect on price at all, since correlation coefficient is so low. Will plan not to include in the modeling process. It's perhaps worth noting as an exception, since homeowners might THINK this rating would have an impact on price, but it apparently does not. Most homes are average, and being above or below average largely does not impact price.
#
# ### Grade
# - Most grades are either a 7 or 8, which makes sense because 7 is average and 8 is just above average.
# - Grade is correlated with price at about 0.6, which is pretty high.
#
# ### Sq Ft Above
# - Correlate with price at about 0.6, which makes sense because it's similar to total sqft living space
# - Probably will not include this in model since it's covered by sq ft living.
#
# ### Sq Ft Basement
# - Tried converting to a binary 'has basement' column and re-running exploration, but it's actually less correlated with price than the actual square feet.
# - There does not look to be much of a linear relationship.
#
# ### Yr Built
# - Very low correlation between year built and price. Looking at the scatterplot, it's clear that houses built quite a while ago can still command prices in the same range as houses built recently.
#
# ### Yr Renovated
# - Only a 0.11 correlation with price.
# - Engineered a column to reflect years since renovated, where if the home had been renovated it reflected the number of years between reno and sale, and if it hadn't been renovated it reflected the total age in years. This had only about a correlation of -0.09, which is a smaller absolute value from year renovated itself.
# - There definitely doesn't appear to be much of a linear relationship between price and anything related to having renovated the house recently.
#
# ### Zipcode
# - There doesn't appear to be much of a general correlation between zip code and price
#
# ### *Overall Summary*
# - The IVs with highest correlation to price are sqft_living, grade, and bathrooms. sqft_above is also highly correlated but related to sqft_living.

# %% [markdown]
# ## Feature Engineering
#
# I've already engineered a few columns as part of my initial exploration, but none of them really seemed to get a better correlation with price than they did in their original forms.
#
# Let's try creating a few more engineered features to see if they end up being correlated to price more than the ones we have.

# %%
# Create a ratio of bathrooms to bedrooms
df_raw['bath_per_bed'] = df_raw.apply(lambda x : x['bathrooms'] / x['bedrooms'], 
                                      axis=1)

# %%
# Create a ratio of sqft living to bedrooms
# larger values means more living space for the number of bedrooms
df_raw['sqft_per_bed'] = df_raw.apply(lambda x : x['sqft_living'] / x['bedrooms'], 
                                      axis=1)

# %%
# Create a ratio of sqft living to bathrooms
# larger values means more living space for the number of bathrooms
df_raw['sqft_per_bath'] = df_raw.apply(lambda x : x['sqft_living'] / x['bathrooms'], 
                                      axis=1)

# %%
# check out exploratory summary for three new variables
explore_data(['sqft_per_bath', 'sqft_per_bed', 'bath_per_bed'], df_raw, 'price')
# Out:
# ---------------------------------------------------------------------------
# Summary of Data for column: sqft_per_bath
# ---------------------------------------------------------------------------
# count    21397.000000
# mean      1005.739618
# std        293.586196
# min        265.454545
# 25%        800.000000
# 50%        970.000000
# 75%       1165.714286
# max       4600.000000
# Name: sqft_per_bath, dtype: float64
# Data is NOT normal with p-statistic = 0.0
#
# ---------------------------------------------------------------------------
# Summary of Data for column: sqft_per_bed
# ---------------------------------------------------------------------------
# count    21397.000000
# mean       618.750577
# std        215.821684
# min        163.333333
# 25%        470.000000
# 50%        576.666667
# 75%        723.333333
# max       3420.000000
# Name: sqft_per_bed, dtype: float64
# Data is NOT normal with p-statistic = 0.0
#
# ...

# %% [markdown]
# sqft_per_bed has the best correlation with price.

# %%
# Correlation matrix for IVs
corr_1 = df_raw.drop(['price', 'lat', 'long', 'id', 'date', 
             'sqft_living15', 'sqft_lot15', 'price', 'year_sold'], axis=1).corr()

fig, ax = plt.subplots(figsize=(12, 8))

sns.heatmap(np.abs(corr_1), cmap='Reds', 
            annot=corr_1.apply(lambda x: np.round(x, 2)));

# %% [markdown]
# Most of the features that correlate highly to each other (0.7 or higher) represent a feature I engineered from another.
#
# Sq Ft Living and Sq Ft Above are also highly correlated, which I expected since Sq Ft Above is included in Living.
#
# However, the following variables appear to be multicollinear:
# - Sq ft living, and Grade, at 0.76
#     - It seems reasonable that when people build houses with more square footage, they also tend to spring for finer finishings.
# - Sq ft living, and Bathrooms, at 0.76
#     - It seems reasonable that larger houses have more bathrooms
# - Grade and Bathrooms is very close, at 0.67
#
# Unfortunately, these were the ONLY variables with any decent degree of correlation with price.
#
# I'll need to try out a few different models, maybe using one each of these 3 to avoid multicollinearity issues.
#
# In addition to help answer my questions for Acme, perhaps I can split up the houses into above and below average or median sq ft living, to see if the results look different. Perhaps certain predictors have more weight on houses at the different ends of the spectrum of characteristics.

# %% [markdown]
# # MODEL

# %% [markdown]
# ## Data Modeling
# I plan to model in a few ways:
# 1. Standardize variables, then use statsmodels to do an initial multiple regression with all variables.
#
#
# ***
# Questions to consider:
# * How did you analyze or model the data?
# * How did you iterate on your initial approach to make it better?
# * Why are these choices appropriate given the data and the business problem?
# ***

# %%
df_ols = df_raw.drop(['lat', 'long', 'id', 'date', 'zipcode', 
                      'condition_new', 'sqft_living15', 'sqft_lot15', 
                      'year_sold'], axis=1).copy()

df_ols.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21397 entries, 0 to 21596
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             21397 non-null  float64
#  1   bedrooms          21397 non-null  int64
#  2   bathrooms         21397 non-null  float64
#  3   sqft_living       21397 non-null  int64
#  4   sqft_lot          21397 non-null  int64
#  5   floors            21397 non-null  int64
#  6   waterfront        21397 non-null  float64
#  7   view              21397 non-null  int64
#  8   condition         21397 non-null  int64
#  9   grade             21397 non-null  int64
#  10  sqft_above        21397 non-null  int64
#  11  sqft_basement     21397 non-null  float64
#  12  yr_built          21397 non-null  int64
#  13  yr_renovated      21397 non-null  float64
#  14  has_basement      21397 non-null  int64
#  15  years_since_reno  21397 non-null  float64
# ...

# %% [markdown]
# ## Initial OLS Model

# %%
# Create formula
ivs = '+'.join(df_ols.drop('price', axis=1).columns)
formula = 'price' + '~' + ivs

# standardize data
df_z = df_ols.drop('price', axis=1)
df_z.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21397 entries, 0 to 21596
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   bedrooms          21397 non-null  int64
#  1   bathrooms         21397 non-null  float64
#  2   sqft_living       21397 non-null  int64
#  3   sqft_lot          21397 non-null  int64
#  4   floors            21397 non-null  int64
#  5   waterfront        21397 non-null  float64
#  6   view              21397 non-null  int64
#  7   condition         21397 non-null  int64
#  8   grade             21397 non-null  int64
#  9   sqft_above        21397 non-null  int64
#  10  sqft_basement     21397 non-null  float64
#  11  yr_built          21397 non-null  int64
#  12  yr_renovated      21397 non-null  float64
#  13  has_basement      21397 non-null  int64
#  14  years_since_reno  21397 non-null  float64
#  15  bath_per_bed      21397 non-null  float64
# ...

# %%
from scipy import stats
df_scipy_z = pd.DataFrame(stats.zscore(df_z), columns=df_z.columns)
df_scipy_z.describe()
# Out:
#            bedrooms     bathrooms   sqft_living      sqft_lot        floors  \
# count  2.139700e+04  2.139700e+04  2.139700e+04  2.139700e+04  2.139700e+04
# mean   2.390946e-17  1.168907e-16  2.656607e-17  2.656607e-17  2.019021e-16
# std    1.000023e+00  1.000023e+00  1.000023e+00  1.000023e+00  1.000023e+00
# min   -2.628131e+00 -2.105723e+00 -1.864486e+00 -3.518294e-01 -8.112369e-01
# 25%   -4.128810e-01 -4.793466e-01 -7.108741e-01 -2.430468e-01 -8.112369e-01
# 50%   -4.128810e-01  1.712039e-01 -1.776006e-01 -1.810262e-01 -8.112369e-01
# 75%    6.947438e-01  4.964792e-01  5.080369e-01 -1.068760e-01  1.000478e+00
# max    8.448117e+00  7.652535e+00  1.246860e+01  3.937883e+01  2.812192e+00
#
#          waterfront          view     condition         grade    sqft_above  \
# count  2.139700e+04  2.139700e+04  2.139700e+04  2.139700e+04  2.139700e+04
# mean   2.656607e-17 -6.774348e-17  1.222039e-16 -2.125286e-16 -2.125286e-17
# ...

# %%
df_z = (df_z - np.mean(df_z)) / np.std(df_z, ddof=0)
df_z = pd.concat([df_z, df_ols[['price']]], axis=1)
df_z.describe()
# Out:
#            bedrooms     bathrooms   sqft_living      sqft_lot        floors  \
# count  2.139700e+04  2.139700e+04  2.139700e+04  2.139700e+04  2.139700e+04
# mean   2.390946e-17  1.168907e-16  2.656607e-17  2.656607e-17  2.019021e-16
# std    1.000023e+00  1.000023e+00  1.000023e+00  1.000023e+00  1.000023e+00
# min   -2.628131e+00 -2.105723e+00 -1.864486e+00 -3.518294e-01 -8.112369e-01
# 25%   -4.128810e-01 -4.793466e-01 -7.108741e-01 -2.430468e-01 -8.112369e-01
# 50%   -4.128810e-01  1.712039e-01 -1.776006e-01 -1.810262e-01 -8.112369e-01
# 75%    6.947438e-01  4.964792e-01  5.080369e-01 -1.068760e-01  1.000478e+00
# max    8.448117e+00  7.652535e+00  1.246860e+01  3.937883e+01  2.812192e+00
#
#          waterfront          view     condition         grade    sqft_above  \
# count  2.139700e+04  2.139700e+04  2.139700e+04  2.139700e+04  2.139700e+04
# mean   2.656607e-17 -6.774348e-17  1.222039e-16 -2.125286e-16 -2.125286e-17
# ...

# %%
# Fit model using statsmodels
model1 = ols(formula=formula, data=df_z).fit()
model1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.662
# Model:                            OLS   Adj. R-squared:                  0.662
# Method:                 Least Squares   F-statistic:                     2327.
# Date:                Mon, 12 Apr 2021   Prob (F-statistic):               0.00
# Time:                        20:12:10   Log-Likelihood:            -2.9296e+05
# No. Observations:               21397   AIC:                         5.860e+05
# Df Residuals:                   21378   BIC:                         5.861e+05
# Df Model:                          18
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# ...

# %% [markdown]
# - R squared and adjusted R squared are both pretty decent actually at 0.662. Not great, but not terrible.
# - Durbin-Watson of 1.98 is between 1.5 and 2.5, so it seems our residuals are pretty homoscedastic
# - But Conditions are kinda high so there are almost certain multicollinear variables, which I expected

# %%
# let's remove some of the variables I'm fairly certain are multicollinear
# because they're derived from each other, and the features I added
cols_to_drop = ['sqft_above', 'has_basement', 'years_since_reno', 
                'bath_per_bed', 'sqft_per_bed', 'sqft_per_bath', 'price']

ivs = '+'.join(df_z.drop(labels=cols_to_drop, axis=1).columns)
formula = 'price' + '~' + ivs

model2 = ols(formula=formula, data=df_z).fit()
model2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.652
# Model:                            OLS   Adj. R-squared:                  0.651
# Method:                 Least Squares   F-statistic:                     3334.
# Date:                Mon, 12 Apr 2021   Prob (F-statistic):               0.00
# Time:                        20:34:52   Log-Likelihood:            -2.9328e+05
# No. Observations:               21397   AIC:                         5.866e+05
# Df Residuals:                   21384   BIC:                         5.867e+05
# Df Model:                          12
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %% [markdown]
# - Well our R squared went down a bit, to 0.652 or so.
# - But our conditions are also way down, so I think the multicollinearity is less pronounced.
#
# There's only one p-statistic that's above 0.05 alpha level. Let's trade it in for the has_basement feature I engineered and see if that helps at all?

# %%
cols_to_drop = ['sqft_above', 'sqft_basement', 'years_since_reno', 
                'bath_per_bed', 'sqft_per_bed', 'sqft_per_bath', 'price']

ivs = '+'.join(df_z.drop(labels=cols_to_drop, axis=1).columns)
formula = 'price' + '~' + ivs

model3 = ols(formula=formula, data=df_z).fit()
model3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.652
# Model:                            OLS   Adj. R-squared:                  0.651
# Method:                 Least Squares   F-statistic:                     3334.
# Date:                Mon, 12 Apr 2021   Prob (F-statistic):               0.00
# Time:                        20:40:47   Log-Likelihood:            -2.9328e+05
# No. Observations:               21397   AIC:                         5.866e+05
# Df Residuals:                   21384   BIC:                         5.867e+05
# Df Model:                          12
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %% [markdown]
# Basement has a smaller p value but still too high.
#
# One last try with the basement removed completely.

# %%
cols_to_drop = ['sqft_above', 'sqft_basement', 'sqft_above', 'years_since_reno', 
                'bath_per_bed', 'sqft_per_bed', 'sqft_per_bath', 'price', 
                'has_basement', 'yr_renovated']

ivs = '+'.join(df_z.drop(labels=cols_to_drop, axis=1).columns)
formula = 'price' + '~' + ivs

model4 = ols(formula=formula, data=df_z).fit()
model4.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.651
# Model:                            OLS   Adj. R-squared:                  0.651
# Method:                 Least Squares   F-statistic:                     3998.
# Date:                Mon, 12 Apr 2021   Prob (F-statistic):               0.00
# Time:                        20:43:00   Log-Likelihood:            -2.9329e+05
# No. Observations:               21397   AIC:                         5.866e+05
# Df Residuals:                   21386   BIC:                         5.867e+05
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept    5.418e+05   1484.367    365.012      0.000    5.39e+05    5.45e+05
# ...

# %% [markdown]
# # iNTERPRET

# %% [markdown]
# Evaluate how well your work solves the stated business problem.
#
# ***
# Questions to consider:
# * How do you interpret the results?
# * How well does your model fit your data? How much better is this than your baseline model?
# * How confident are you that your results would generalize beyond the data you have?
# * How confident are you that this model would benefit the business if put into use?
# ***

# %% [markdown]
# # CONCLUSIONS & RECOMMENDATIONS

# %% [markdown]
# Provide your conclusions about the work you've done, including any limitations or next steps.
#
# ***
# Questions to consider:
# * What would you recommend the business do as a result of this work?
# * What are some reasons why your analysis might not fully solve the business problem?
# * What else could you do in the future to improve this project?
# ***
